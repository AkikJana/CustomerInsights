# %%
import pandas as pd
import numpy as np
df_abs = pd.read_csv("Laptop_Data (1).csv")

# %%
df_abs.head()
# Out:
#                                            Sentences  \
# 0  I charge it at night and skip taking the cord ...
# 1  it is of high quality , has a killer GUI , is ...
# 2  Easy to start up and does not overheat as much...
# 3     Great laptop that offers many great features !
# 4  One night I turned the freaking thing off afte...
#
#                                              Opinion  Unnamed: 2  Unnamed: 3  \
# 0                          [([16, 17], [15], 'POS')]         NaN         NaN
# 1  [([4], [3], 'POS'), ([9], [8], 'POS'), ([26], ...         NaN         NaN
# 2                             [([2, 3], [0], 'POS')]         NaN         NaN
# 3                                [([6], [5], 'POS')]         NaN         NaN
# 4  [([21], [20], 'NEG'), ([23], [25], 'NEG'), ([2...         NaN         NaN
#
#    Unnamed: 4 Unnamed: 5
# 0         NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import re

# %%
df.columns
# Out:
# Index(['Title', 'Abs', 'CAR-T', 'Trials', 'Trial Documents',
#        'Twitter Reactions', 'Primary Prdts', 'Secondary Prdts', 'Industry',
#        'MOAs (Title)', 'MOAs (Prdts/Abs)', 'Disease', 'Biomarkers',
#        'Diagnostic Tests', 'Authors', 'Affiliations', 'Disclosures', 'Topic',
#        'Details', 'Category'],
#       dtype='object')

# %%
df['Primary Prdts'][0]
# Out:
# 'Enhertu (fam-trastuzumab deruxtecan-nxki) / Daiichi Sankyo, AstraZeneca; Kadcyla (ado-trastuzumab emtansine) / Roche'

# %%
if ';' in df['Primary Prdts'][0]:    
    print(df['Primary Prdts'][0].split(';'))
# Out:
# ['Enhertu (fam-trastuzumab deruxtecan-nxki) / Daiichi Sankyo, AstraZeneca', ' Kadcyla (ado-trastuzumab emtansine) / Roche']

# %%
df['Primary Prdts'].unique()
# Out:
# array(['Enhertu (fam-trastuzumab deruxtecan-nxki) / Daiichi Sankyo, AstraZeneca; Kadcyla (ado-trastuzumab emtansine) / Roche',
#        'Piqray (alpelisib) / Novartis', nan,
#        'veliparib (ABT-888) / AbbVie',
#        'Keytruda (pembrolizumab) / Merck (MSD); nemvaleukin alfa (ALKS 4230) / Alkermes',
#        'Cotellic (cobimetinib) / Exelixis, Roche; Zelboraf (vemurafenib) / Roche',
#        'Vectibix (panitumumab) / Amgen, Takeda',
#        'capecitabine / Generic mfg.; temozolomide / Generic mfg.',
#        'Onivyde (nanoliposomal irinotecan) / Servier, Ipsen, Takeda',
#        'Cabometyx (cabozantinib tablet) / Takeda, Exelixis, Ipsen; Tecentriq (atezolizumab) / Roche',
#        'Baizeâ€™an (tislelizumab) / BeiGene, Novartis',
#        'Jevtana (cabazitaxel) / Sanofi, Emcure; Pluvicto (lutetium Lu 177 vipivotide tetraxetan) / Novartis',
#        'Pluvicto (lutetium Lu 177 vipivotide tetraxetan) / Novartis',
#        'rezvilutamide (SHR3680) / Jiangsu Hengrui Medicine',
# ...

# %%
df['Primary Prdts'].unique
# Out:
# <bound method Series.unique of 0      Enhertu (fam-trastuzumab deruxtecan-nxki) / Da...
# 1                          Piqray (alpelisib) / Novartis
# 2                                                    NaN
# 3                           veliparib (ABT-888) / AbbVie
# 4      Keytruda (pembrolizumab) / Merck (MSD); nemval...
#                              ...
# 386                           anastrozole / Generic mfg.
# 387                             cisplatin / Generic mfg.
# 388       Lynparza (olaparib) / Merck (MSD), AstraZeneca
# 389                         Jemperli (dostarlimab) / GSK
# 390            Xpovio (selinexor) / Karyopharm, Menarini
# Name: Primary Prdts, Length: 391, dtype: object>

# %%
regex1 = r"\w+\s\(?([\w\-\s]+)\)?\s\/\s([\w\s\,]+)"
regex2 = r"([\w\s\-]+)\s\/\s([\w\s\,\.]+)"
DrugCol=[]
CompanyCol=[]
for i in  df['Primary Prdts']:
    drug=[]
    company=[]
    print(type(i))
    if pd.isna(i):
        DrugCol.append(drug)
        CompanyCol.append(company)
        continue
    #match1 = re.search(regex1,i)
    match2 = re.finditer(regex2,i)
    match2find = re.search(regex2,i)
    match3 = re.finditer(regex1,i)
    match3find = re.search(regex1,i)
    
    if match2find != None:
        print(match2)
        for m in match2:
            print ("Match at index match2 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            print ("Drug: %s" % (m.group(1)))
            print ("Company: %s" % (m.group(2)))
            drug.append(m.group(1))
            company.append(m.group(2))
            
    elif match3find != None:
        print(match3)
        for m in match3:
            print ("Match at index %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            print ("Drug: %s" % (m.group(1)))
            print ("Company: %s" % (m.group(2)))
            drug.append(m.group(1))
            company.append(m.group(2))

    

    else:
        print ("The regex pattern does not match.")
    DrugCol.append(drug)
    CompanyCol.append(company)
print(DrugCol)
print(CompanyCol)
df[DrugCol]=DrugCol
df[CompanyCol]=CompanyCol
# Out:
# <class 'float'>
# <class 'str'>
# ...
# Match at index 0, 32
# Full match: Mekinist (trametinib) / Novartis
# Drug: trametinib
# Company: Novartis
# Match at index 34, 66
# Full match: Tafinlar (dabrafenib) / Novartis
# Drug: dabrafenib
# Company: Novartis
# <class 'float'>
# <class 'str'>
# ...
# Match at index 0, 57
# Full match: Cabometyx (cabozantinib tablet) / Takeda, Exelixis, Ipsen
# Drug: cabozantinib tablet
# Company: Takeda, Exelixis, Ipsen
# <class 'str'>
# ...
# Match at index 0, 42
# Full match: relacorilant (CORT125134) / Corcept Therap
# Drug: CORT125134
# Company: Corcept Therap
# <class 'str'>
# ...
# Match at index 0, 56
# Full match: Yondelis (trabectedin) / Otsuka, PharmaMar, Valeo Pharma
# Drug: trabectedin
# Company: Otsuka, PharmaMar, Valeo Pharma
# <class 'str'>
# ...
# Match at index match2 0, 24
# Full match: cisplatin / Generic mfg.
# Drug: cisplatin
# Company: Generic mfg.
# Match at index match2 25, 50
# Full match:  docetaxel / Generic mfg.
# Drug:  docetaxel
# Company: Generic mfg.
# ...

# %%
df3=pd.DataFrame(DrugCol,columns=['col1','col2','col3'])
df3['col4'] = df3[['col1','col2','col3']].apply(lambda x: ', '.join(x[x.notnull()]), axis = 1)
df3
# Out:
#                      col1        col2  col3                    col4
# 0                    None        None  None
# 1              trametinib  dabrafenib  None  trametinib, dabrafenib
# 2                    None        None  None
# 3     cabozantinib tablet        None  None     cabozantinib tablet
# 4              CORT125134        None  None              CORT125134
# ...                   ...         ...   ...                     ...
# 2433                 None        None  None
# 2434                 None        None  None
# 2435                 None        None  None
# 2436                 None        None  None
# 2437                AFM13        None  None                   AFM13
#
# [2438 rows x 4 columns]

# %%
df3.to_csv('productTest.csv',index=False)

# %%
df3=pd.DataFrame(CompanyCol,columns=['col1','col2','col3'])
df3['col4'] = df3[['col1','col2','col3']].apply(lambda x: ', '.join(x[x.notnull()]), axis = 1)
df3
# Out:
#                          col1      col2  col3                     col4
# 0                        None      None  None
# 1                    Novartis  Novartis  None       Novartis, Novartis
# 2                        None      None  None
# 3     Takeda, Exelixis, Ipsen      None  None  Takeda, Exelixis, Ipsen
# 4              Corcept Therap      None  None           Corcept Therap
# ...                       ...       ...   ...                      ...
# 2433                     None      None  None
# 2434                     None      None  None
# 2435                     None      None  None
# 2436                     None      None  None
# 2437                  Affimed      None  None                  Affimed
#
# [2438 rows x 4 columns]

# %%
df3.to_csv('CompanyTest.csv',index=False)

# %%
df['Trial Ext']
# Out:
# 0        DESTINY-Breast03
# 1                 SOLAR-1
# 2                    P2/3
# 3                 A071102
# 4              ARTISTRY-1
#               ...
# 386                 AIMSS
# 387                 RADIO
# 388    NCI protocol 10250
# 389                GARNET
# 390                SIENDO
# Name: Trial Ext, Length: 391, dtype: object

# %%
regex1 = r"([\w\d]+)\-([\w\d]+)"#wordNum-wordNum
regex2 = r"([\w\d]+)\s([\w\d]+)"#wordNum wordNum
regex3 = r"([\w\d]+)\-([\w\d]+)\s([\w\d\.]+)"#wordNum-wordNum wordNum
regex4 = r"([\w\d]+)\s([\w\d]+)\-([\w\d\.]+)"#wordNum wordNum-wordNum
regex5 = r"([\w\d]+)\s([\w\d]+)\-([\w\d\.]+)"#wordNum wordNum-wordNum
regex6 = r"([\w\d]+)\-([\w\d]+)\-([\w\d\.]+)"#wordNum-wordNum-wordNum
regex7 = r"([\w\d]+)\s([\w\d]+)\/([\w\d]+)"#wordNum wordNum/wordNum
regex8 = r"([\w\d]+)\s([\w\d]+)\s([\w\d\.]+)"#wordNum wordNum wordNum
regexCM = r"CheckMate[\s\-]?(.*)"#CheckMate-Num,CheckMate Num,CheckMateNum
regexKN = r"KEYNOTE[\s\-]?(.*)"#KEYNOTE-Num,KEYNOTE Num,KEYNOTENum

# %%
topicCol=[]
arr=[]
notMatched=[]
for j in df['Trial Ext']:
    temp=j
    
    match3 = re.finditer(regex3,j)
    match3find = re.search(regex3,j)
    match4 = re.finditer(regex4,j)
    match4find = re.search(regex4,j)
    match5 = re.finditer(regex5,j)
    match5find = re.search(regex5,j)
    match6 = re.finditer(regex6,j)
    match6find = re.search(regex6,j)
    match7 = re.finditer(regex7,j)
    match7find = re.search(regex7,j)
    match8 = re.finditer(regex8,j)
    match8find = re.search(regex8,j)
    match1 = re.finditer(regex1,j)
    match1find = re.search(regex1,j)
    match2 = re.finditer(regex2,j)
    match2find = re.search(regex2,j)
    matchCM = re.finditer(regexCM,j)
    matchCMfind = re.search(regexCM,j)
    matchKN = re.finditer(regexKN,j)
    matchKNfind = re.search(regexKN,j)
    
    arr.append(j)
    topicCol.append(j)
    if matchCMfind != None:
        print(matchCM)
        #wordNum wordNum
        for m in matchCM:
            print ("Match at index match2 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = "CheckMate"+m.group(1)
            perm2 = "CheckMate"+"-"+m.group(1)
            perm3 = "CheckMate"+" "+m.group(1)
            perm1_1 = "CM"+m.group(1)
            perm2_1 = "CM"+"-"+m.group(1)
            perm3_1 = "CM"+" "+m.group(1)
        
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter3: %s" % (perm3))
            print ("Iter4: %s" % (perm1_1))
            print ("Iter5: %s" % (perm2_1))
            print ("Iter6: %s" % (perm3_1))
            topicCol.extend([m.group(0)]*6)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm3)
            arr.append(perm1_1)
            arr.append(perm2_1)
            arr.append(perm3_1)
    elif matchKNfind != None:
        print(matchKN)
        #wordNum wordNum
        for m in matchKN:
            print ("Match at index match2 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = "KEYNOTE"+m.group(1)
            perm2 = "KEYNOTE"+"-"+m.group(1)
            perm3 = "KEYNOTE"+" "+m.group(1)
            perm1_1 = "KN"+m.group(1)
            perm2_1 = "KN"+"-"+m.group(1)
            perm3_1 = "KN"+" "+m.group(1)
        
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter3: %s" % (perm3))
            print ("Iter4: %s" % (perm1_1))
            print ("Iter5: %s" % (perm2_1))
            print ("Iter6: %s" % (perm3_1))
            
            topicCol.extend([m.group(0)]*6)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm3)
            arr.append(perm1_1)
            arr.append(perm2_1)
            arr.append(perm3_1)
    
    elif match3find != None:
        print(match3)
        #wordNum-wordNum wordNum
        for m in match3:
            print ("Match at index match3 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)+" "+m.group(3)
            perm2 = m.group(1)+" "+m.group(2)+" "+m.group(3)
            
            perm0_1 = m.group(1)+"-"+m.group(2)+"-"+m.group(3)
            perm0_2 = m.group(1)+"-"+m.group(2)+m.group(3)
            perm1_1 = m.group(1)+m.group(2)+m.group(3)
            perm1_2 = m.group(1)+m.group(2)+"-"+m.group(3)
            perm2_1 = m.group(1)+" "+m.group(2)+"-"+m.group(3)
            perm2_2 = m.group(1)+" "+m.group(2)+m.group(3)
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter0_1: %s" % (perm0_1))
            print ("Iter0_2: %s" % (perm0_2))
            print ("Iter1_1: %s" % (perm1_1))
            print ("Iter1_2: %s" % (perm1_2))
            print ("Iter2_1: %s" % (perm2_1))
            print ("Iter2_2: %s" % (perm2_2))
            
            topicCol.extend([m.group(0)]*8)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm0_1)
            arr.append(perm0_2)
            arr.append(perm1_1)
            arr.append(perm1_2)
            arr.append(perm2_1)
            arr.append(perm2_2)
    elif match4find != None:
        print(match4)
        #wordNum wordNum-wordNum
        for m in match4:
            print ("Match at index match4 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)+"-"+m.group(3)
            perm2 = m.group(1)+"-"+m.group(2)+"-"+m.group(3)
            
            perm0_1 = m.group(1)+" "+m.group(2)+" "+m.group(3)
            perm0_2 = m.group(1)+" "+m.group(2)+m.group(3)
            perm1_1 = m.group(1)+m.group(2)+m.group(3)
            perm1_2 = m.group(1)+m.group(2)+" "+m.group(3)
            perm2_1 = m.group(1)+"-"+m.group(2)+" "+m.group(3)
            perm2_2 = m.group(1)+"-"+m.group(2)+m.group(3)
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter0_1: %s" % (perm0_1))
            print ("Iter0_2: %s" % (perm0_2))
            print ("Iter1_1: %s" % (perm1_1))
            print ("Iter1_2: %s" % (perm1_2))
            print ("Iter2_1: %s" % (perm2_1))
            print ("Iter2_2: %s" % (perm2_2))
            
            topicCol.extend([m.group(0)]*8)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm0_1)
            arr.append(perm0_2)
            arr.append(perm1_1)
            arr.append(perm1_2)
            arr.append(perm2_1)
            arr.append(perm2_2)
           
    elif match6find != None:
        print(match6)
        #wordNum-wordNum-wordNum
        for m in match6:
            print ("Match at index match6 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)+"-"+m.group(3)
            perm2 = m.group(1)+" "+m.group(2)+"-"+m.group(3)
            
            perm0_1 = m.group(1)+"-"+m.group(2)+" "+m.group(3)
            perm0_2 = m.group(1)+"-"+m.group(2)+m.group(3)
            perm1_1 = m.group(1)+m.group(2)+m.group(3)
            perm1_2 = m.group(1)+m.group(2)+" "+m.group(3)
            perm2_1 = m.group(1)+" "+m.group(2)+" "+m.group(3)
            perm2_2 = m.group(1)+" "+m.group(2)+m.group(3)
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter0_1: %s" % (perm0_1))
            print ("Iter0_2: %s" % (perm0_2))
            print ("Iter1_1: %s" % (perm1_1))
            print ("Iter1_2: %s" % (perm1_2))
            print ("Iter2_1: %s" % (perm2_1))
            print ("Iter2_2: %s" % (perm2_2))
            
            topicCol.extend([m.group(0)]*8)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm0_1)
            arr.append(perm0_2)
            arr.append(perm1_1)
            arr.append(perm1_2)
            arr.append(perm2_1)
            arr.append(perm2_2)
    elif match7find != None:
        print(match7)
        #wordNum wordNum/wordNum
        for m in match7:
            print ("Match at index match7 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)+"/"+m.group(3)
            perm2 = m.group(1)+"-"+m.group(2)+"/"+m.group(3)
            
            #perm0_1 = m.group(1)+"-"+m.group(2)+" "+m.group(3)
            #perm0_2 = m.group(1)+"-"+m.group(2)+m.group(3)
            #perm1_1 = m.group(1)+m.group(2)+m.group(3)
            #perm1_2 = m.group(1)+m.group(2)+" "+m.group(3)
            #perm2_1 = m.group(1)+" "+m.group(2)+" "+m.group(3)
            #perm2_2 = m.group(1)+" "+m.group(2)+m.group(3)
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            
            topicCol.extend([m.group(0)]*2)
            arr.append(perm1)
            arr.append(perm2)
            
    elif match8find != None:
        print(match8)
        #wordNum wordNum wordNum
        for m in match8:
            print ("Match at index match8 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)+" "+m.group(3)
            perm2 = m.group(1)+"-"+m.group(2)+" "+m.group(3)
            
            perm0_1 = m.group(1)+" "+m.group(2)+"-"+m.group(3)
            perm0_2 = m.group(1)+" "+m.group(2)+m.group(3)
            perm1_1 = m.group(1)+m.group(2)+m.group(3)
            perm1_2 = m.group(1)+m.group(2)+"-"+m.group(3)
            perm2_1 = m.group(1)+"-"+m.group(2)+"-"+m.group(3)
            perm2_2 = m.group(1)+"-"+m.group(2)+m.group(3)
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            print ("Iter0_1: %s" % (perm0_1))
            print ("Iter0_2: %s" % (perm0_2))
            print ("Iter1_1: %s" % (perm1_1))
            print ("Iter1_2: %s" % (perm1_2))
            print ("Iter2_1: %s" % (perm2_1))
            print ("Iter2_2: %s" % (perm2_2))
            
            topicCol.extend([m.group(0)]*8)
            arr.append(perm1)
            arr.append(perm2)
            arr.append(perm0_1)
            arr.append(perm0_2)
            arr.append(perm1_1)
            arr.append(perm1_2)
            arr.append(perm2_1)
            arr.append(perm2_2)
            
    elif match1find != None:
        print(match1)
        #wordNum-wordNum
        for m in match1:
            print ("Match at index match1 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)
            perm2 = m.group(1)+" "+m.group(2)
        
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            
            topicCol.extend([m.group(0)]*2)
            arr.append(perm1)
            arr.append(perm2)
    elif match2find != None:
        print(match2)
        #wordNum wordNum
        for m in match2:
            print ("Match at index match2 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
            perm1 = m.group(1)+m.group(2)
            perm2 = m.group(1)+"-"+m.group(2)
        
            print ("Iter1: %s" % (perm1))
            print ("Iter2: %s" % (perm2))
            
            topicCol.extend([m.group(0)]*2)
            arr.append(perm1)
            arr.append(perm2)
    else:
        notMatched.append(j)
# Out:
# ...
# Match at index match1 0, 16
# Full match: DESTINY-Breast03
# Iter1: DESTINYBreast03
# Iter2: DESTINY Breast03
# ...
# Match at index match1 0, 7
# Full match: SOLAR-1
# Iter1: SOLAR1
# Iter2: SOLAR 1
# ...
# Match at index match1 0, 10
# Full match: ARTISTRY-1
# Iter1: ARTISTRY1
# Iter2: ARTISTRY 1
# ...
# Match at index match3 0, 16
# Full match: ECOG-ACRIN E2211
# Iter1: ECOGACRIN E2211
# Iter2: ECOG ACRIN E2211
# Iter0_1: ECOG-ACRIN-E2211
# Iter0_2: ECOG-ACRINE2211
# Iter1_1: ECOGACRINE2211
# Iter1_2: ECOGACRIN-E2211
# Iter2_1: ECOG ACRIN-E2211
# Iter2_2: ECOG ACRINE2211
# ...
# Match at index match1 0, 6
# Full match: NET-02
# Iter1: NET02
# Iter2: NET 02
# ...
# Match at index match1 0, 10
# Full match: COSMIC-021
# Iter1: COSMIC021
# Iter2: COSMIC 021
# ...
# Match at index match1 0, 8
# Full match: Truce-02
# Iter1: Truce02
# Iter2: Truce 02
# ...
# Match at index match1 0, 8
# Full match: SHR-3680
# Iter1: SHR3680
# Iter2: SHR 3680
# ...
# Match at index match2 0, 11
# Full match: KEYNOTE-826
# Iter1: KEYNOTE826
# ...

# %%
print(notMatched)
print(arr)
print(topicCol)
# Out:
# ['P2/3', 'A071102', 'TAPUR', 'IMPROVE', 'SEQUENCE', 'TheraP', 'VISION', 'VISION', 'PESCO', 'IDHENTIFY', 'P3', 'IDARA', 'NADIM', 'S1800A', 'CHRYSALIS', 'Tricotel', 'SIOPEN', 'PALLAS', 'NeoSTAR', 'PEARL', 'BYLieve', 'MATCH', 'NIVACOR', 'P3', 'NICHE', 'CheckMate142', 'NXCEL1311', 'AURA', 'CLEAR', 'MAGNITUDE', 'PROPEL', 'plasmaMATCH', 'BioItaLEE', 'INVINCIBLE', 'SAFIA', 'SUMMIT', 'KORNELIA', 'IMpassion130', 'ASCENT', 'PALOMA3', 'Overstep', 'RACTAC', 'GEINOGLAS', 'P2', 'GLORIA', 'ROSALIE', 'P3', 'GARNET', 'FORTITUDE', 'NEBULA', 'CheckMate057', 'P1/2', 'MANTRA', 'TAPUR', 'TRESR', 'COMMIT', 'PanaMa', 'PanaMa', 'LIBImAb', 'SEAMARK', 'CORINTH', 'AVETUXIRI', 'PanaMa', 'AtezoTRIBE', 'PanaMa', 'SUMMIT', 'HIMALAYA', 'REGOMUNE', 'PANDA', 'RAMSES', 'TRITICC', 'P2', 'AuspiCiOus', 'EPOC2003', 'TEDOPAM', 'NEONAX', 'REGOMUNE', 'IMMUTACE', 'IMMUNIB', 'TRIPLET', 'ZIRCON', 'SAMETA', 'Spencer', 'P2', 'ABATE', 'INSPIRE', 'DANUBE ', 'A031701', 'NIVOREN', 'CREST', 'UNISoN', 'CASPAR', 'VERACITY', 'ATLAS', 'FAA
# ...

# %%
d = {'tags':arr , 'topic':topicCol}

# %%
df3=pd.DataFrame(d)

# %%
df3.to_csv('studyTagsTest.csv',index=False)

# %%
for j in df['Trial Ext']:
    temp=j
    arr=[]
    while(True):
        
        if j.contains(' '):
            word1=temp[:temp.find(' ')]
            word2=temp[temp.find(' '):]
            newWord=word1+"-"+word2
            newWord2=word1+word2           
            arr.append(newWord)
            arr.append(newWord2)

# %%
opinionRex=r',\s\[([\d\,\s]*)\],\s\''

# %%
matchOP = re.finditer(regex3,j)
matchOPfind = re.search(regex3,j)

# %%
import re

# %%
df['Opinion_extracted'] = ''
C = 0 
for j in df['Opinion']:    
    matchOP = re.finditer(opinionRex,j)
    matchOPfind = re.search(opinionRex,j)
    array1=[]
    if matchOPfind != None:        
        print(matchOP)
        
        #wordNum wordNum
        for m in matchOP:
            #print ("Match at index match2 %s, %s" % (m.start(), m.end()))
            print ("Full match: %s" % (m.group(0)))
# Out:
# ...
# Full match: , [15], '
# ...
# Full match: , [3], '
# Full match: , [8], '
# Full match: , [25], '
# Full match: , [29], '
# ...
# Full match: , [0], '
# ...
# Full match: , [5], '
# ...
# Full match: , [20], '
# Full match: , [25], '
# Full match: , [29], '
# Full match: , [34], '
# ...
# Full match: , [14], '
# ...
# Full match: , [1], '
# ...
# Full match: , [3], '
# Full match: , [9], '
# ...
# Full match: , [10, 11, 12, 13], '
# ...
# Full match: , [21], '
# ...
# Full match: , [12], '
# ...
# Full match: , [17], '
# ...
# Full match: , [3], '
# ...
# Full match: , [11], '
# ...
# Full match: , [1], '
# Full match: , [1], '
# ...
# Full match: , [1], '
# Full match: , [1], '
# Full match: , [14], '
# ...
# Full match: , [2, 3, 4], '
# ...
# Full match: , [7], '
# ...
# Full match: , [2], '
# ...
# Full match: , [6], '
# ...
# Full match: , [8], '
# ...
# Full match: , [4], '
# ...
# Full match: , [16], '
# ...
# Full match: , [4], '
# ...
# Full match: , [7, 8], '
# ...
# Full match: , [0], '
# ...
# Full match: , [7], '
# Full match: , [10], '
# ...
# Full match: , [6, 7, 8], '
# ...
# Full match: , [8, 9], '
# ...
# Full match: , [13], '
# ...

# %%
df_abs['abs_num']=''
for i in range(0,len(df_abs)):
    absRegex= r',\s\[([\d\,\s]*)\],\s\''
    matchABSfind = re.search(absRegex,df_abs['Opinion'][i])
    matchABS = re.finditer(absRegex,df_abs['Opinion'][i])
    
    if matchABSfind != None:
        temp=[]
        for m in matchABS:
            temp.append(m.group(1))
        df_abs['abs_num'][i] = temp
# Out:
# <ipython-input-6-2a3205a7673a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_abs['abs_num'][i] = temp

# %% [markdown]
# df_abs.head()

# %%
df_abs.head()
# Out:
#                                            Sentences  \
# 0  I charge it at night and skip taking the cord ...
# 1  it is of high quality , has a killer GUI , is ...
# 2  Easy to start up and does not overheat as much...
# 3     Great laptop that offers many great features !
# 4  One night I turned the freaking thing off afte...
#
#                                              Opinion  Unnamed: 2  Unnamed: 3  \
# 0                          [([16, 17], [15], 'POS')]         NaN         NaN
# 1  [([4], [3], 'POS'), ([9], [8], 'POS'), ([26], ...         NaN         NaN
# 2                             [([2, 3], [0], 'POS')]         NaN         NaN
# 3                                [([6], [5], 'POS')]         NaN         NaN
# 4  [([21], [20], 'NEG'), ([23], [25], 'NEG'), ([2...         NaN         NaN
#
#    Unnamed: 4 Unnamed: 5           abs_num
# 0         NaN                         [15]
# 1         NaN        NaN    [3, 8, 25, 29]
# 2         NaN        NaN               [0]
# ...

# %%
# df_abs['Sentences'][1]
df_abs['New_Column'] = ""
for i in range(0,len(df_abs)):
    indexCount = 0
    for word in df_abs['Sentences'][i]:
        list1=[]
        for k in range(0,len(df_abs['abs_num'][i])):
            print(k)
            print(int(df_abs['abs_num'][i][k]))
            if indexCount == int(df_abs['abs_num'][i][k]):
                list1.append(word)
                df_abs['New_Column'][i] = list1
            indexCount = +1
# Out:
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 15
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# 3
# 1
# 8
# 2
# 25
# 3
# 29
# 0
# ...

# %%
df_abs
# Out:
#                                              Sentences  \
# 0    I charge it at night and skip taking the cord ...
# 1    it is of high quality , has a killer GUI , is ...
# 2    Easy to start up and does not overheat as much...
# 3       Great laptop that offers many great features !
# 4    One night I turned the freaking thing off afte...
# ..                                                 ...
# 901  The laptop is relatively simple to use , thoug...
# 902                      No tutorials on the display .
# 903                  The touch pad is among the best .
# 904  We also use Paralles so we can run virtual mac...
# 905  How Toshiba handles the repair seems to vary ,...
#
#                                                Opinion  Unnamed: 2  \
# 0                            [([16, 17], [15], 'POS')]         NaN
# 1    [([4], [3], 'POS'), ([9], [8], 'POS'), ([26], ...         NaN
# 2                               [([2, 3], [0], 'POS')]         NaN
# ...

# %%
# df_abs['Sentences'][1]
df_abs['New_Coulmn'] = ""
for i in range(0,len(df_abs)):
    indexCount = 0
    words=[]
    arr=df_abs['Sentences'][i].split()
    for word in df_abs['abs_num'][i]:
        words.append(arr[word])
    df_abs['New_Coulmn']=words
            

        
# str1In = "@SWOG S1801 results at #ESMO2022 Presidential Symp: Patients w high-risk melanoma who got #pembrolizumab both before &amp; after surgery had significantly lower risk of recurrence than those who got IO drug only after"
# str2 = "#pembrolizumab"
# str1 = str1In.split()


# indexCount = 0
#for word in str1:
#     if word == str2:
#        print("Your word was found at index point",int(indexCount))
# #     else:
# #        print("",int(indexCount))
#     indexCount += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a3d0f03c4a7e> in <module>
#       6     arr=df_abs['Sentences'][i].split()
#       7     for word in df_abs['abs_num'][i]:
# ----> 8         words.append(arr[word])
#       9     df_abs['New_Coulmn']=words
#      10
#
# TypeError: list indices must be integers or slices, not str

# %%
df_abs
# Out:
#                                              Sentences  \
# 0    I charge it at night and skip taking the cord ...
# 1    it is of high quality , has a killer GUI , is ...
# 2    Easy to start up and does not overheat as much...
# 3       Great laptop that offers many great features !
# 4    One night I turned the freaking thing off afte...
# ..                                                 ...
# 901  The laptop is relatively simple to use , thoug...
# 902                      No tutorials on the display .
# 903                  The touch pad is among the best .
# 904  We also use Paralles so we can run virtual mac...
# 905  How Toshiba handles the repair seems to vary ,...
#
#                                                Opinion  Unnamed: 2  \
# 0                            [([16, 17], [15], 'POS')]         NaN
# 1    [([4], [3], 'POS'), ([9], [8], 'POS'), ([26], ...         NaN
# 2                               [([2, 3], [0], 'POS')]         NaN
# ...
